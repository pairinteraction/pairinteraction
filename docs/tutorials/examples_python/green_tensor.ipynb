# %% [markdown]
# # Green Tensor

# %%
# %pip install -q matplotlib numpy pairinteraction

import matplotlib.pyplot as plt
import numpy as np
import pairinteraction as pi
from pairinteraction.green_tensor import GreenTensorCavity, GreenTensorFreeSpace
from pairinteraction.visualization import plot_pair_potential

if pi.Database.get_global_database() is None:
    pi.Database.initialize_global_database(download_missing=True)
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
n = 85
ket = pi.KetAtom("Sr88_singlet", n=n, l=n - 1, m=n - 1)

# Create single-atom basis and system
basis = pi.BasisAtom("Sr88_singlet", n=(n - 1, n + 1), l=(n - 2, n), m=(n - 2, n))
system = pi.SystemAtom(basis)
system.set_magnetic_field([0, 0, 1], "gauss")
system.set_electric_field([0, 0, 1], "V/cm")
system.diagonalize()

# Create two-atom basis
pair_energy_ghz = 2 * system.get_corresponding_energy(ket, unit="GHz")
energy_range_ghz = (pair_energy_ghz - 1, pair_energy_ghz + 1)
basis_pair = pi.BasisPair([system, system], energy=energy_range_ghz, energy_unit="GHz")

# %% [markdown]
# ## SystemPair without custom Green Tensor for comparison

# %%
distances = np.linspace(1, 4, 100)  # micrometers
system_pairs = [
    pi.SystemPair(basis_pair).set_distance(d, unit="micrometer") for d in distances
]
pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)

# %% [markdown]
# ## SystemPair with custom Vacuum Green Tensor

# %%
system_pairs: list[pi.SystemPair] = []

distances = np.linspace(1, 4, 100)  # micrometer
for i, distance in enumerate(distances):
    print(f"{i + 1}/{len(distances)}", end="\r")
    gt = GreenTensorFreeSpace()
    gt.set_atom_positions([0, 0, 0], [distance, 0, 0], "micrometer")
    gt.set_electric_permitivity(1)
    system_pair = pi.SystemPair(basis_pair).set_green_tensor(gt, omega_steps=10)
    system_pairs.append(system_pair)

pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)
# Out:
# 1/100
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 9
#       7     gt.set_atom_positions([0, 0, 0], [distance, 0, 0], "micrometer")
#       8     gt.set_electric_permitivity(1)
# ----> 9     system_pair = pi.SystemPair(basis_pair).set_green_tensor(gt, omega_steps=10)
#      10     system_pairs.append(system_pair)
#      12 pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
#
# File ~/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/system/system_pair.py:193, in SystemPair.set_green_tensor(self, green_tensor, omega_steps)
#     190 energies_au = [ket.get_energy("hartree") for ket in self.basis.kets]
#     191 omega_max = max(energies_au) - min(energies_au)
# --> 193 gti = green_tensor.get_green_tensor_interpolator(0, omega_max, omega_steps, omega_unit="hartree")
#     194 self.set_green_tensor_interpolator(gti)
#     195 return self
#
# File ~/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/green_tensor_base.py:160, in GreenTensorBase.get_green_tensor_interpolator(self, omega_min, omega_max, omega_steps, omega_unit)
#     151 """Get a GreenTensorInterpolator from this Green tensor.
#     152
#     153 The GreenTensorInterpolator can be used for the interaction of a SystemPair.
#    (...)    157
#     158 """
#     159 omega_list = list(np.linspace(omega_min, omega_max, omega_steps))
# --> 160 gt_list = [self.get_dipole_dipole(omega, omega_unit, unit="hartree") for omega in omega_list]
#     162 gti = GreenTensorInterpolator()
#     163 gti.set_from_cartesian(1, 1, gt_list, tensor_unit="hartree", omegas=omega_list, omegas_unit=omega_unit)
#
# File ~/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/green_tensor_base.py:140, in GreenTensorBase.get_dipole_dipole(self, omega, omega_unit, unit)
#     123 """Calculate the dipole dipole Green tensor in cartesian coordinates.
#     124
#     125 This is a 3x3 matrix in the basis [x1, y1, z1] x [x2, y2, z2].
#    (...)    137
#     138 """
#     139 omega_au = QuantityScalar.convert_user_to_au(omega, omega_unit, "energy")
# --> 140 gt_au = self._get_dipole_dipole_au(omega_au)
#     142 dimension: list[Dimension] = ["green_tensor_00"] + 3 * ["inverse_distance"]  # type: ignore [assignment]
#     143 return QuantityArray.convert_au_to_user(gt_au, dimension, unit)
#
# File ~/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/green_tensor_free_space.py:42, in GreenTensorFreeSpace._get_dipole_dipole_au(self, omega_au)
#      38 omega = 2 * np.pi * ureg.Quantity(omega_au, "hartree").to("Hz", "spectroscopy").magnitude  # this is the angular frequency
#      41 # TODO calculate Green tensor
# ---> 42 raise NotImplementedError("GreenTensorFreeSpace is not yet implemented yet.")
#      44 return gt
#
# NotImplementedError: GreenTensorFreeSpace is not yet implemented yet.

# %% [markdown]
# ## SystemPair with custom Green Tensor in a cavity

# %%
system_pairs: list[pi.SystemPair] = []

distances = np.linspace(1, 4, 100)  # micrometer
cavity_height = 100  # micrometer
eps1, eps2 = 3.9, 11.7
for i, distance in enumerate(distances):
    print(f"{i + 1}/{len(distances)}", end="\r")
    gt = GreenTensorCavity()
    gt.set_atom_positions([0, 0, 0], [distance, 0, 0], "micrometer")
    gt.set_electric_permitivity(1)
    gt.set_surface_positions(-cavity_height / 2, cavity_height / 2, "micrometer")
    gt.set_electric_permitivity_surfaces(eps1, eps2)
    system_pair = pi.SystemPair(basis_pair).set_green_tensor(gt)
    system_pairs.append(system_pair)

pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)

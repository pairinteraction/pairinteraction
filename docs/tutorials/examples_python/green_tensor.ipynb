# %% [markdown]
# # Green Tensor

# %%
# %pip install -q matplotlib numpy pairinteraction

import matplotlib.pyplot as plt
import numpy as np
import pairinteraction as pi
from pairinteraction.green_tensor import GreenTensorCavity, GreenTensorFreeSpace
from pairinteraction.visualization import plot_pair_potential

if pi.Database.get_global_database() is None:
    pi.Database.initialize_global_database(download_missing=False)
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
n = 85
ket = pi.KetAtom("Sr88_singlet", n=n, l=n - 1, m=n - 1)

# Create single-atom basis and system
basis = pi.BasisAtom("Sr88_singlet", n=(n - 1, n + 1), l=(n - 2, n), m=(n - 2, n))
system = pi.SystemAtom(basis)
system.set_magnetic_field([0, 0, 1], "gauss")
system.set_electric_field([0, 0, 1], "V/cm")
system.diagonalize()

# Create two-atom basis
pair_energy_ghz = 2 * system.get_corresponding_energy(ket, unit="GHz")
energy_range_ghz = (pair_energy_ghz - 1, pair_energy_ghz + 1)
basis_pair = pi.BasisPair([system, system], energy=energy_range_ghz, energy_unit="GHz")

# %% [markdown]
# ## SystemPair without custom Green Tensor for comparison

# %%
distances = np.linspace(1, 4, 100)  # micrometers
system_pairs = [
    pi.SystemPair(basis_pair).set_distance(d, unit="micrometer") for d in distances
]
pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)

# %% [markdown]
# ## SystemPair with custom Vacuum Green Tensor

# %%
system_pairs: list[pi.SystemPair] = []

distances = np.linspace(1, 4, 100)  # micrometer
for i, distance in enumerate(distances):
    print(f"{i + 1}/{len(distances)}", end="\r")
    gt = GreenTensorFreeSpace()
    gt.set_atom_positions([0, 0, 0], [distance, 0, 0], "micrometer")
    gt.set_electric_permitivity(1)
    system_pair = pi.SystemPair(basis_pair).set_green_tensor(gt, omega_steps=1)
    system_pairs.append(system_pair)

pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)
# Out:
# 100/100

# %% [markdown]
# ## SystemPair with custom Green Tensor in a cavity

# %%
system_pairs: list[pi.SystemPair] = []

distances = np.linspace(1, 4, 20)  # micrometer
cavity_height = 100  # micrometer
eps1, eps2 = 3.9, 11.7
for i, distance in enumerate(distances):
    print(f"{i + 1}/{len(distances)}", end="\r")
    gt = GreenTensorCavity()
    gt.set_atom_positions([0, 0, 0], [distance, 0, 0], "micrometer")
    gt.set_electric_permitivity(1)
    gt.set_surface_positions(-cavity_height / 2, cavity_height / 2, "micrometer")
    gt.set_electric_permitivity_surfaces(eps1, eps2)
    system_pair = pi.SystemPair(basis_pair).set_green_tensor(gt, omega_steps=1)
    system_pairs.append(system_pair)

pi.diagonalize(system_pairs, diagonalizer="eigen", sort_by_energy=True)
fig, ax = plot_pair_potential(system_pairs, (ket, ket))
plt.show(fig)
# Out:
# 1/20
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:109: RuntimeWarning: overflow encountered in exp
#   return 1 - r_plus * r_minus * np.exp(2j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:109: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - r_plus * r_minus * np.exp(2j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:126: RuntimeWarning: invalid value encountered in scalar divide
#   return (
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   return (
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:129: RuntimeWarning: overflow encountered in exp
#   + 2 * r_plus * r_minus * np.cos(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:129: RuntimeWarning: invalid value encountered in scalar multiply
#   + 2 * r_plus * r_minus * np.cos(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:150: RuntimeWarning: overflow encountered in exp
#   - 2 * r_plus * r_minus * np.cos(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:150: RuntimeWarning: invalid value encountered in scalar multiply
#   - 2 * r_plus * r_minus * np.cos(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:426: RuntimeWarning: overflow encountered in exp
#   * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:435: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   real_real, _ = quad(real_part_real, 2 * k_maj, upper_limit * np.real(k0), limit=1000, epsrel=1e-9)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:436: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   imag_real, _ = quad(imag_part_real, 2 * k_maj, upper_limit * np.real(k0), limit=1000, epsrel=1e-9)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:168: RuntimeWarning: invalid value encountered in scalar divide
#   return (
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:171: RuntimeWarning: overflow encountered in exp
#   + 2j * r_plus * r_minus * np.sin(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:171: RuntimeWarning: invalid value encountered in scalar multiply
#   + 2j * r_plus * r_minus * np.sin(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:435: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   real_real, _ = quad(real_part_real, 2 * k_maj, upper_limit * np.real(k0), limit=1000, epsrel=1e-9)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:189: RuntimeWarning: invalid value encountered in scalar divide
#   return (
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:192: RuntimeWarning: overflow encountered in exp
#   - 2j * r_plus * r_minus * np.sin(kz * z_ab) * np.exp(1j * kz * h)
# /itp3/home/moegerle/Desktop/PairInteraction/pairinteraction_green_tensor/src/pairinteraction/green_tensor/utils.py:192: RuntimeWarning: invalid value encountered in scalar multiply
#   - 2j * r_plus * r_minus * np.sin(kz * z_ab) * np.exp(1j * kz * h)
# 20/20

# %%
print(system_pairs[0].get_eigenenergies())
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan] bohr ** 2 * electron_mass / atomic_unit_of_time ** 2

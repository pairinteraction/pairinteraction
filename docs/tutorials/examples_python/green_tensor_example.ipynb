# %%
from pairinteraction.green_tensor import (
    GreenTensorCavity,
    GreenTensorFreeSpace,
    GreenTensorSurface,
)

# %%
gt = GreenTensorFreeSpace()
gt.set_atom_positions([0, 0, 0], [2, 0, 0], "nanometer")
gt.set_electric_permitivity(1)

tensor = gt.get_dipole_dipole(omega=1e6, omega_unit="Hz")

print(tensor)
# Out:
# [[ 1.78801662e+30+585.43245882j  0.00000000e+00  +0.j   0.00000000e+00  +0.j        ] [ 0.00000000e+00  +0.j         -8.94008308e+29-292.71622941j   0.00000000e+00  +0.j        ] [ 0.00000000e+00  +0.j          0.00000000e+00  +0.j  -8.94008308e+29-292.71622941j]] electron_mass / atomic_unit_of_current ** 2 / atomic_unit_of_time ** 4 / bohr

# %%
gt = GreenTensorSurface()
gt.set_atom_positions([0, 0, 0], [5, 0, 0], "micrometer")
gt.set_electric_permitivity(1)
gt.set_surface_position(z=-1, unit="micrometer")
gt.set_electric_permitivity_surface(3 + 2j)

tensor = gt.get_dipole_dipole(omega=1e6, omega_unit="Hz")

print(tensor)
# Out:
# [[ 7.08472025e+19-1.45286203e+19j -8.70281823e+03-2.90093941e+03j  -2.84255615e+19-9.47518717e+18j] [-8.70281823e+03-2.90093941e+03j -2.97384889e+19+9.15934759e+18j   3.48112729e+03+1.16037576e+03j] [ 2.84255615e+19+9.47518717e+18j -3.48112729e+03-1.16037576e+03j  -7.33243499e+19-5.36927273e+18j]] electron_mass / atomic_unit_of_current ** 2 / atomic_unit_of_time ** 4 / bohr

# %%
gt = GreenTensorCavity()
gt.set_atom_positions([0, 0, 0], [2, 0, 0], "nanometer")
gt.set_electric_permitivity(1)
gt.set_surface_positions(z1=1, z2=-1, unit="centimeter")
gt.set_electric_permitivity_surfaces(epsilon1=3 + 2j, epsilon2=4 + 1j)

tensor = gt.get_dipole_dipole(omega=1e6, omega_unit="Hz")

print(tensor)
# Out:
# [[ 1.14433063e+29+2.17341708e+08j -2.81569939e-20-6.36768041e-21j  -8.18183685e+02-1.88401307e+02j] [-2.81569939e-20-6.36768041e-21j -5.72165317e+28+2.17341871e+08j   9.96721059e-14+2.30593690e-14j] [ 8.18183685e+02+1.88401307e+02j -9.96721059e-14-2.30593690e-14j  -5.72165317e+28+6.01687122e+08j]] electron_mass / atomic_unit_of_current ** 2 / atomic_unit_of_time ** 4 / bohr
